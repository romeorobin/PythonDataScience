# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.linspace(0, 20, 100)
plt.figure(figsize=(14, 3))
plt.xlabel("x", fontsize=14)       
plt.ylabel("cos(x), cos(x*0.5)", fontsize=14)   
plt.plot(x, np.cos(x), x, np.cos(x*0.5), "r--")
